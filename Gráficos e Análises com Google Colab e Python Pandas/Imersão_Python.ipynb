# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelKitoco/Imersao-Python-do-excel-analise-de-dado/blob/main/Gr%C3%A1ficos%20e%20An%C3%A1lises%20com%20Google%20Colab%20e%20Python%20Pandas/Imers%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aula 02 da imersão**

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/acoes.xlsx", sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Variacao em dinheiro  \
# ...

# %%
df_total_acoes = pd.read_excel("/content/acoes.xlsx", sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticket = pd.read_excel("/content/acoes.xlsx", sheet_name="Ticker")
df_ticket
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/acoes.xlsx", sheet_name="Chat GPT")
df_chatgpt
# Out:
#              Empresa           Segmento  Idade (Anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração            81
# 2          Petrobras     Petróleo e Gás            69
# 3             Suzano   Papel e Celulose            98
# 4       CPFL Energia   Energia Elétrica           110
# ..               ...                ...           ...
# 73  Carrefour Brasil             Varejo            35
# 74       Casas Bahia             Varejo            67
# 75          Localiza  Aluguel de Carros            48
# 76               CVC            Turismo            49
# 77               GOL   Transporte Aéreo            21
#
# [78 rows x 3 columns]
